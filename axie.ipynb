# %%
import csv
import pandas as pd
import numpy as np

import statsmodels.api as sm

from numpy.random import randn
from numpy.random import seed
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.cluster import KMeans


import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel (r'C:/Users/Runxin Li(Sally)/Desktop/S22/URP/axie_query.xlsx',sheet_name="axie_query") 
df = pd.DataFrame(data, 
	columns= ['id','class','birthDate','level','breedCount','price','hp','speed','skill','morale','random_children_id'])
df['class'].replace(['Aquatic','Beast','Bird','Bug','Dawn','Dusk','Mech','Plant','Reptile'],
	[0,1,2,3,4,5,6,7,8],inplace=True)

# %%
breedCountDf = df[['breedCount','price']].copy()
# Out:
#       breedCount        price
# 0              2  4234.612500
# 1              2   162.609120
# 2              0   181.671867
# 3              0   164.733823
# 4              1  6774.500000
# 5              2    60.970500
# 6              0   169.362500
# 7              0   169.362500
# 8              2   101.617500
# 9              2   128.715500
# 10             1   152.408250
# 11             0   270.948000
# 12             1   413.195700
# 13             3   135.474000
# 14             2   169.342500
# 15             0  1693.425000
# 16             2   152.408250
# 17             1    33.862400
# 18             3   101.587200
# 19             0   440.211200
# 20             0   253.965750
# 21             0   108.358720
# 22             2    38.941415
# 23             3   670.469580
# 24             4   338.621000
# 25             1   118.517350
# 26             0   108.358720
# 27             3   338.621000
# 28             2   135.448400
# 29             0   284.441640
# ...

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(breedCountDf)
    distortions.append(kmeanModel.inertia_)
plt.figure(figsize=(10,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters= 3,random_state=100)


#visualization
label = kmeans.fit_predict(breedCountDf)
# Out:
# [0 0 0 ... 0 0 0]

# %%
print(breedCountDf.values[:, 0])
plt.scatter(breedCountDf.values[:, 0], breedCountDf.values[:, 1],s=200);
plt.show()
# Out:
# [2. 2. 0. ... 0. 0. 2.]

# %%
plt.scatter(breedCountDf.values[:, 0], breedCountDf.values[:, 1], c=label, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.xlabel('breedcount')
plt.ylabel('auction price')
plt.title('The k-means clustering of breedcount and prices')
plt.show()

# %%
speedDf = df[['speed','price']].copy()
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(speedDf)
    distortions.append(kmeanModel.inertia_)
plt.figure(figsize=(10,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters= 3,random_state=100)
#visualization
label = kmeans.fit_predict(speedDf)
plt.scatter(speedDf.values[:, 0], speedDf.values[:, 1],s=200);
plt.show()

# %%
plt.scatter(speedDf.values[:, 0], speedDf.values[:, 1], c=label, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.xlabel('speed')
plt.ylabel('price')
plt.title('The k-means clustering of speed and prices')
plt.show()

# %%
df.head()
sns.scatterplot(x="skill", y="class", data=df)
plt.show()

# %%
sns.scatterplot(x="speed", y="class", data=df)
plt.show()

# %%
classDf = df[['class','price']].copy()
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(speedDf)
    distortions.append(kmeanModel.inertia_)
plt.figure(figsize=(10,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters= 3,random_state=100)
#visualization
label = kmeans.fit_predict(classDf)
plt.scatter(classDf.values[:, 0], classDf.values[:, 1],s=200);
plt.show()

# %%
skillDf = df[['skill','price']].copy()
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(skillDf)
    distortions.append(kmeanModel.inertia_)
plt.figure(figsize=(10,5))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters= 3,random_state=100)
#visualization
label = kmeans.fit_predict(skillDf)
plt.scatter(skillDf.values[:, 0], skillDf.values[:, 1],s=200);
plt.show()

# %%
plt.scatter(skillDf.values[:, 0], skillDf.values[:, 1], c=label, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.xlabel('skill')
plt.ylabel('price')
plt.title('The k-means clustering of skill and prices')
plt.show()

# %%
classDf = df[['class','price']].copy()
kmeans = KMeans(n_clusters= 3,random_state=100)
#visualization
label = kmeans.fit_predict(classDf)
plt.scatter(classDf.values[:, 0], classDf.values[:, 1],s=200);
plt.show()

# %%
plt.scatter(classDf.values[:, 0], classDf.values[:, 1], c=label, s=50, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);
plt.xlabel('class')
plt.ylabel('price')
plt.title('The k-means clustering of class and prices')
plt.show()

# %%
speedht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='speed')
speedhtp = sns.heatmap(speedht,vmin=0,
                vmax=1000)

# %%
skillht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='skill')
skillhtp = sns.heatmap(skillht,vmin=0,
                vmax=1000)

# %%
hpht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='hp')
hphtp = sns.heatmap(hpht,vmin=0,
                vmax=1000)

# %%
breedCountht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='breedCount')
breedCounthtp = sns.heatmap(breedCountht,vmin=0,
                vmax=1000)

# %%
breedCountht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='breedCount')
breedCounthtp = sns.heatmap(breedCountht,vmin=5000,
                vmax=10000)

# %%
moraleht=pd.pivot_table(df, values='price', 
                     index=['class'], 
                     columns='morale')
moralehtp = sns.heatmap(moraleht,vmin=0,
                vmax=1000)
